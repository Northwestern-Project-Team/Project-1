# %%
# Dependencies
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import matplotlib
import scipy.stats as st
import seaborn as sns; sns.set();
from sklearn import datasets

# %%
# Name of the CSV file
csv_path1 = 'googleplaystore.csv'
csv_path2 = 'AppleStore.csv'

# %%
# The read the CSV file in pandas
googlestore = pd.read_csv(csv_path1)
googlestore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design     1-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design     8-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %%
applestore = pd.read_csv(csv_path2)

applestore.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %%
applestore.rename(columns={'track_name':'App',
                          'size_bytes':'Size',
                          'price':'Price',
                          'rating_count_tot':'Reviews',
                          'user_rating':'Rating',
                          'cont_rating':'Content Rating',
                          'prime_genre':'Category'}, 
                 inplace=True)
 
applestore.head()
# Out:
#    Unnamed: 0         id                                                App  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#         Size currency  Price  Reviews  rating_count_ver  Rating  \
# 0  100788224      USD   3.99    21292                26     4.0
# 1  158578688      USD   0.00   161065                26     4.0
# 2  100524032      USD   0.00   188583              2822     3.5
# 3  128512000      USD   0.00   262241               649     4.0
# 4   92774400      USD   0.00   985920              5320     4.5
#
#    user_rating_ver     ver Content Rating      Category  sup_devices.num  \
# 0              4.5   6.3.5             4+         Games               38
# 1              3.5   8.2.2             4+  Productivity               37
# 2              4.5   5.0.0             4+       Weather               37
# 3              4.5  5.10.0            12+      Shopping               37
# 4              5.0   7.5.1             4+     Reference               37
#
#    ipadSc_urls.num  lang.num  vpp_lic
# 0                5        10        1
# 1                5        23        1
# 2                5         3        1
# 3                5         9        1
# 4                5        45        1

# %%
# Delete column "Current Ver" , "Android Ver" and "Genres"
del googlestore["Current Ver"]
del googlestore["Android Ver"] 
del googlestore["Genres"] 
del applestore["rating_count_ver"] 
del applestore["user_rating_ver"]
del applestore["ver"]
del applestore["sup_devices.num"]
del applestore["ipadSc_urls.num"]
del applestore["lang.num"]
del applestore["vpp_lic"]
del applestore["Unnamed: 0"]
del applestore["id"]

# %%
applestore.head()
# Out:
#                                                  App       Size currency  \
# 0                                    PAC-MAN Premium  100788224      USD
# 1                          Evernote - stay organized  158578688      USD
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts  100524032      USD
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...  128512000      USD
# 4                                              Bible   92774400      USD
#
#    Price  Reviews  Rating Content Rating      Category
# 0   3.99    21292     4.0             4+         Games
# 1   0.00   161065     4.0             4+  Productivity
# 2   0.00   188583     3.5             4+       Weather
# 3   0.00   262241     4.0            12+      Shopping
# 4   0.00   985920     4.5             4+     Reference

# %%
# Identify incomplete rows
googlestore.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Last Updated      10841
# dtype: int64

# %%
# Drop all rows with missing information
googlestore = googlestore.dropna(how='any')

# %%
# Verify dropped rows
googlestore.count()
# Out:
# App               9366
# Category          9366
# Rating            9366
# Reviews           9366
# Size              9366
# Installs          9366
# Type              9366
# Price             9366
# Content Rating    9366
# Last Updated      9366
# dtype: int64

# %%
applestore.count()
# Out:
# App               7197
# Size              7197
# currency          7197
# Price             7197
# Reviews           7197
# Rating            7197
# Content Rating    7197
# Category          7197
# dtype: int64

# %%
# The "Reviews" and "Price" column are the wrong data types. They should be numeric.
googlestore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Last Updated       object
# dtype: object

# %%
# Convert the datatype of 'Reviews' column
googlestore['Reviews'] = pd.to_numeric(googlestore['Reviews'])

# Remove dollar sign and convert the datatype of 'Price' column
googlestore['Price'] = googlestore['Price'].str.replace('$', '')
googlestore['Price'] = pd.to_numeric(googlestore['Price'])

# %%
# Remove + sign and convert the datatype of 'Installs' column
googlestore['Installs'] = googlestore['Installs'].str.replace(",","")
googlestore['Installs'] = googlestore['Installs'].apply(lambda x: x.strip("+"))
googlestore['Installs']=googlestore['Installs'].astype(float)

# %%
# Make size into numeric
googlestore['Size'].replace('Varies with device', np.nan, inplace = True)
googlestore['Size']=googlestore['Size'].str.extract(r'([\d\.]+)', expand=False).astype(float) * \
googlestore['Size'].str.extract(r'([kM]+)', expand=False).fillna(1).replace(['k','M'],[1,1000]).astype(int)

# %%
# Replace _ sign to space in 'Category' column
googlestore['Category'] = googlestore['Category'].str.replace('_', ' ')

# %%
# Verify datatypes have been changed
googlestore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Last Updated       object
# dtype: object

# %%
applestore.dtypes
# Out:
# App                object
# Size                int64
# currency           object
# Price             float64
# Reviews             int64
# Rating            float64
# Content Rating     object
# Category           object
# dtype: object

# %%
# Push the cleaned dataset to a new CSV file
# googlestore.to_csv("googlestore_clean.csv",
#                   encoding="utf-8", index=False, header=True)

# %%
# Display a statistical overview
googlestore.describe()
# Out:
#             Rating       Reviews           Size      Installs        Price
# count  9366.000000  9.366000e+03    7729.000000  9.366000e+03  9366.000000
# mean      4.191757  5.140498e+05   22957.606870  1.789744e+07     0.960928
# std       0.515219  3.144042e+06   23445.491095  9.123822e+07    15.816585
# min       1.000000  1.000000e+00       8.500000  1.000000e+00     0.000000
# 25%       4.000000  1.862500e+02    5300.000000  1.000000e+04     0.000000
# 50%       4.300000  5.930500e+03   14000.000000  5.000000e+05     0.000000
# 75%       4.500000  8.153275e+04   33000.000000  5.000000e+06     0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09   400.000000

# %% [markdown]
# # Which categories have the highest number of available apps?

# %%
# Display an overview of the Category column
googlestore['Category'].value_counts().sum()
# Out:
# 9366

# %%
print(f"The Google Play Store have {googlestore['Category'].nunique()} categories")

print("The Google Play Store categories are:", googlestore['Category'].unique())
# Out:
# The Google Play Store have 33 categories
# The Google Play Store categories are: ['ART AND DESIGN' 'AUTO AND VEHICLES' 'BEAUTY' 'BOOKS AND REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD AND DRINK' 'HEALTH AND FITNESS' 'HOUSE AND HOME'
#  'LIBRARIES AND DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL AND LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO PLAYERS'
#  'NEWS AND MAGAZINES' 'MAPS AND NAVIGATION']

# %%
print(f" In Google Play Store,  the Top three categories have most numbers of apps are {googlestore['Category'].value_counts().index[0]}, {googlestore['Category'].value_counts().index[1]} and {googlestore['Category'].value_counts().index[2]}.")
# Out:
#  In Google Play Store,  the Top three categories have most numbers of apps are FAMILY, GAME and TOOLS.

# %%
applestore['Category'].value_counts()
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: Category, dtype: int64

# %%
print(f"The Apple Store have {applestore['Category'].nunique()} categories")
print("The Apple Store categories are:", applestore['Category'].unique())
# Out:
# The Apple Store have 23 categories
# The Apple Store categories are: ['Games' 'Productivity' 'Weather' 'Shopping' 'Reference' 'Finance' 'Music'
#  'Utilities' 'Travel' 'Social Networking' 'Sports' 'Business'
#  'Health & Fitness' 'Entertainment' 'Photo & Video' 'Navigation'
#  'Education' 'Lifestyle' 'Food & Drink' 'News' 'Book' 'Medical' 'Catalogs']

# %%
print(f" In Apple Store,  the Top three categories have most numbers of apps are {applestore['Category'].value_counts().index[0]}, {applestore['Category'].value_counts().index[1]} and {applestore['Category'].value_counts().index[2]}.")
# Out:
#  In Apple Store,  the Top three categories have most numbers of apps are Games, Entertainment and Education.

# %%
def plotchart(tab): 
    plot = sns.catplot(x=tab,y=compare, data=dataset, kind=formats, height = 10,
    palette = "Set1", order= orders)
    plot.set_xticklabels(rotation=75, ha="center")
    plot = plot.set_ylabels(tab)
    plt.title(title,size = 20)
    plt.savefig(f"{title}.jpg")

tab = "Category"
compare = None
dataset = googlestore
title = 'Number of Apps in each category (Google Play Store)'
orders= googlestore["Category"].value_counts().index
formats = "count"

plotchart(tab)

# %%
tab = "Category"
compare = None
dataset = applestore
title = 'Number of Apps in each category (Apple Store)'
orders= applestore["Category"].value_counts().index
formats = "count"

plotchart(tab)

# %% [markdown]
# ### Which categories have the highest number of available apps?
# Conclusion:  Game category has the most number of apps on the market

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = googlestore['Category'].value_counts().index
data = googlestore['Category'].value_counts()

matplotlib.rcParams['font.size'] = 15

fig, ax = plt.subplots(figsize=(17, 17))
ax.pie(data,  autopct='%1.1f%%', startangle=90, pctdistance=0.75)
plt.legend(labels, loc="center")

#draw the middle circle
centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.savefig(f"Catagory Pie Chart.jpg")
plt.show()

# %% [markdown]
# # Which categories have the highest number of installs?

# %%
# Which categories have the highest number of installs?
group= googlestore.groupby(googlestore['Category'])
sum_installs = group["Installs"].sum()
sort_installs = sum_installs.sort_values(ascending=False)
print(sum_installs.sum())
print(sort_installs)
# Out:
# 167627457938.0
# Category
# GAME                   3.508586e+10
# COMMUNICATION          3.264724e+10
# PRODUCTIVITY           1.417607e+10
# SOCIAL                 1.406984e+10
# TOOLS                  1.145072e+10
# FAMILY                 1.025770e+10
# PHOTOGRAPHY            1.008824e+10
# NEWS AND MAGAZINES     7.496211e+09
# TRAVEL AND LOCAL       6.868859e+09
# VIDEO PLAYERS          6.221897e+09
# SHOPPING               3.247832e+09
# ENTERTAINMENT          2.869160e+09
# PERSONALIZATION        2.325353e+09
# BOOKS AND REFERENCE    1.921292e+09
# SPORTS                 1.751131e+09
# HEALTH AND FITNESS     1.583056e+09
# BUSINESS               1.001768e+09
# FINANCE                8.766124e+08
# EDUCATION              8.713520e+08
# MAPS AND NAVIGATION    7.242676e+08
# LIFESTYLE              5.375611e+08
# WEATHER                4.260965e+08
# FOOD AND DRINK         2.737778e+08
# DATING                 2.642951e+08
# HOUSE AND HOME         1.685820e+08
# ART AND DESIGN         1.242331e+08
# LIBRARIES AND DEMO     6.208300e+07
# COMICS                 5.603610e+07
# MEDICAL                5.320558e+07
# AUTO AND VEHICLES      5.312980e+07
# PARENTING              3.111611e+07
# BEAUTY                 2.691620e+07
# EVENTS                 1.594941e+07
# Name: Installs, dtype: float64

# %%
# Bar chart for highest number of installs cross catagories
installs_plot = sort_installs.plot(kind="bar")
installs_plot.set_xticklabels(sort_installs.index, rotation = 90,ha="center")
# Configure plot and ticks
plt.title("Categories Vs. Number of installs")
plt.xlabel("Categories")
plt.ylabel("Number of installs")
# Set textual properties
plt.tight_layout()# Show plot
plt.savefig("Categories Vs. Number of installs.jpg")

# %%
print(f" In Google Play Store,  the category has the highest number of installs is {sort_installs.index[0]}.")
# Out:
#  In Google Play Store,  the category has the highest number of installs is GAME.

# %% [markdown]
# # What is the average price per category? (discounting free apps)

# %%
# find paid apps for Price is not equal to 0 
googlestore_df= googlestore[googlestore.Price != 0]
googlestore_df.head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 290  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 291                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
#
#      Reviews     Size  Installs  Type  Price Content Rating Last Updated
# 234    11442   6800.0  100000.0  Paid   4.99       Everyone    25-Mar-18
# 235    10295  39000.0  100000.0  Paid   4.99       Everyone    11-Apr-17
# 290    11442   6800.0  100000.0  Paid   4.99       Everyone    25-Mar-18
# 291    10295  39000.0  100000.0  Paid   4.99       Everyone    11-Apr-17
# 427    18247      NaN  100000.0  Paid   3.99       Everyone     5-Jul-18

# %%
average_price = googlestore_df.groupby(["Category"])['Price'].mean()
sort_price = average_price.sort_values(ascending=False)
# sort_price.style.format({'Average Price': '${:.2f}'})
sort_price
# Out:
# Category
# FINANCE                187.682308
# LIFESTYLE              108.937778
# FAMILY                  14.177407
# MEDICAL                 11.853864
# BUSINESS                 6.762727
# DATING                   5.740000
# MAPS AND NAVIGATION      5.390000
# PHOTOGRAPHY              4.902222
# PARENTING                4.790000
# TRAVEL AND LOCAL         4.686250
# EDUCATION                4.490000
# FOOD AND DRINK           4.240000
# SPORTS                   4.236818
# WEATHER                  4.204286
# ENTERTAINMENT            3.990000
# PRODUCTIVITY             3.940000
# HEALTH AND FITNESS       3.781667
# GAME                     3.641039
# TOOLS                    3.300000
# BOOKS AND REFERENCE      2.985000
# SHOPPING                 2.740000
# VIDEO PLAYERS            2.615000
# COMMUNICATION            2.576818
# NEWS AND MAGAZINES       1.990000
# AUTO AND VEHICLES        1.990000
# ART AND DESIGN           1.990000
# PERSONALIZATION          1.906866
# SOCIAL                   0.990000
# Name: Price, dtype: float64

# %%
price_plot = sort_price.plot(kind="bar")

price_plot.set_xticklabels(sort_price.index, rotation = 90,ha="center")
# Configure plot and ticks

plt.title("Categories Vs. Number of installs")
plt.xlabel("Categories")
plt.ylabel("Number of installs")
# Set textual properties

plt.tight_layout()# Show plot
plt.savefig("Categories Vs. Number of installs.jpg")

# %%
#What is the average price per category? (discounting free apps)
average_price = googlestore_df.groupby(["Category"])['Price'].mean()
average_price_sorted = average_price.sort_values(ascending = False)
average_price_df = pd.DataFrame({'Average Price': average_price_sorted})
average_price_df.style.format({'Average Price': '${:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Price</th>    </tr>    <tr>        <th class="index_name level0" >Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row0" class="row_heading level0 row0" >FINANCE</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row0_col0" class="data row0 col0" >$187.68</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row1" class="row_heading level0 row1" >LIFESTYLE</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row1_col0" class="data row1 col0" >$108.94</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row2" class="row_heading level0 row2" >FAMILY</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row2_col0" class="data row2 col0" >$14.18</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row3" class="row_heading level0 row3" >MEDICAL</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row3_col0" class="data row3 col0" >$11.85</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row4" class="row_heading level0 row4" >BUSINESS</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row4_col0" class="data row4 col0" >$6.76</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row5" class="row_heading level0 row5" >DATING</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row5_col0" class="data row5 col0" >$5.74</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row6" class="row_heading level0 row6" >MAPS AND NAVIGATION</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row6_col0" class="data row6 col0" >$5.39</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row7" class="row_heading level0 row7" >PHOTOGRAPHY</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row7_col0" class="data row7 col0" >$4.90</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row8" class="row_heading level0 row8" >PARENTING</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row8_col0" class="data row8 col0" >$4.79</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row9" class="row_heading level0 row9" >TRAVEL AND LOCAL</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row9_col0" class="data row9 col0" >$4.69</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row10" class="row_heading level0 row10" >EDUCATION</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row10_col0" class="data row10 col0" >$4.49</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row11" class="row_heading level0 row11" >FOOD AND DRINK</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row11_col0" class="data row11 col0" >$4.24</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row12" class="row_heading level0 row12" >SPORTS</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row12_col0" class="data row12 col0" >$4.24</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row13" class="row_heading level0 row13" >WEATHER</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row13_col0" class="data row13 col0" >$4.20</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row14" class="row_heading level0 row14" >ENTERTAINMENT</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row14_col0" class="data row14 col0" >$3.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row15" class="row_heading level0 row15" >PRODUCTIVITY</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row15_col0" class="data row15 col0" >$3.94</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row16" class="row_heading level0 row16" >HEALTH AND FITNESS</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row16_col0" class="data row16 col0" >$3.78</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row17" class="row_heading level0 row17" >GAME</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row17_col0" class="data row17 col0" >$3.64</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row18" class="row_heading level0 row18" >TOOLS</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row18_col0" class="data row18 col0" >$3.30</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row19" class="row_heading level0 row19" >BOOKS AND REFERENCE</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row19_col0" class="data row19 col0" >$2.98</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row20" class="row_heading level0 row20" >SHOPPING</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row20_col0" class="data row20 col0" >$2.74</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row21" class="row_heading level0 row21" >VIDEO PLAYERS</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row21_col0" class="data row21 col0" >$2.62</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row22" class="row_heading level0 row22" >COMMUNICATION</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row22_col0" class="data row22 col0" >$2.58</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row23" class="row_heading level0 row23" >NEWS AND MAGAZINES</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row23_col0" class="data row23 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row24" class="row_heading level0 row24" >AUTO AND VEHICLES</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row24_col0" class="data row24 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row25" class="row_heading level0 row25" >ART AND DESIGN</th>
#                         <td id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04row25_col0" class="data row25 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d79ba9e6_3666_11ea_8444_b88584bb7b04level0_row26" class="row_heading level0 row26" >PERSONALIZATION</th>
#                         <td id="T_d79ba9e6_3666_11ea_84

# %% [markdown]
# # What distribution of free v. paid apps across categories

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
#labels = googlestore_df['Category'].value_counts().index
#data = googlestore_df['Category'].value_counts()

types = googlestore['Type'].value_counts()
type_labels= googlestore['Type'].value_counts().index

matplotlib.rcParams['font.size'] = 15
fig, ax = plt.subplots(figsize=(8, 8))

#ax.pie(data,  autopct='%1.1f%%', startangle=90, pctdistance=0.75)
#plt.legend(labels, loc="center")

ax.pie(types,labels=type_labels, radius=0.8,startangle=90, autopct='%1.1f%%', labeldistance=1.05)

#draw circle
#centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0)
#fig = plt.gcf()
#fig.gca().add_artist(centre_circle)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.savefig(os.path.join('paid_free_percents.png'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-67d05187f6fd> in <module>
#      20 ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#      21 plt.tight_layout()
# ---> 22 plt.savefig(os.path.join('paid_free_percents.png'))
#      23 plt.show()
#
# NameError: name 'os' is not defined

# %%
csv_path3 = 'free_paid_cleaned.csv'

# %%
free_paid = pd.read_csv(csv_path3)
free_paid
# Out:
#                Category  Free  Paid
# 0        ART AND DESIGN    59     3
# 1     AUTO AND VEHICLES    72     1
# 2                BEAUTY    42     0
# 3   BOOKS AND REFERENCE   170     8
# 4              BUSINESS   292    11
# 5                COMICS    58     0
# 6         COMMUNICATION   306    22
# 7                DATING   191     4
# 8             EDUCATION   151     4
# 9         ENTERTAINMENT   147     2
# 10               EVENTS    45     0
# 11               FAMILY  1585   162
# 12              FINANCE   310    13
# 13       FOOD AND DRINK   107     2
# 14                 GAME  1020    77
# 15   HEALTH AND FITNESS   285    12
# 16       HOUSE AND HOME    76     0
# 17   LIBRARIES AND DEMO    65     0
# 18            LIFESTYLE   296    18
# 19  MAPS AND NAVIGATION   119     5
# 20              MEDICAL   262    88
# 21   NEWS AND MAGAZINES   231     2
# 22            PARENTING    48     2
# 23      PERSONALIZATION   247    67
# 24          PHOTOGRAPHY   299    18
# 25         PRODUCTIVITY   333    18
# 26             SHOPPING   236     2
# 27               SOCIAL   257     2
# 28               SPORTS   297    22
# 29                TOOLS   671    63
# 30     TRAVEL AND LOCAL   218     8
# 31        VIDEO PLAYERS   156     4
# 32              WEATHER    68     7

# %%
fig= plt.figure(figsize=(10,6))
plt.plot( 'Category', 'Free', data=free_paid, marker='o', markerfacecolor='blue', markersize=5, 
         color="black", linewidth=1)

plt.plot( 'Category', 'Paid', data=free_paid, marker='o', markerfacecolor='orange', markersize=5, 
         color="black", linewidth=1)

plt.title('Distribution of Paid and Free Apps by Category', fontsize = 20)
plt.ylabel('Number of Apps')
plt.xticks(rotation='vertical', fontsize=10)
plt.legend(loc='best')
plt.savefig(os.path.join('paid_free_price.png'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-4f4990d67c9b> in <module>
#      10 plt.xticks(rotation='vertical', fontsize=10)
#      11 plt.legend(loc='best')
# ---> 12 plt.savefig(os.path.join('paid_free_price.png'))
#      13 plt.show()
#
# NameError: name 'os' is not defined

# %% [markdown]
# # What is the correlation between Installs and Reviews?

# %%
googlestore.plot(kind="scatter", y="Installs", x="Reviews", grid=True, figsize=(10,10), title="Installs VS Reviews")
plt.xscale('log')
plt.yscale('log')
plt.title('Reviews-Installs ', size = 20)
plt.savefig(f"installs_reviews.jpg")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
installs = googlestore.iloc[:,5]
reviews = googlestore.iloc[:,3]
correlation = st.pearsonr(installs,reviews)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.64

# %%
# What is the correlation between the rating and installs?
plt.figure(figsize=(10,10))
plt.scatter(x=googlestore['Rating'], y=googlestore['Installs'], color = 'green')
g = sns.lineplot(x="Rating", y="Installs",color="yellow",data=googlestore)
plt.yscale('log')
plt.xlabel('Rating')
plt.ylabel('Installs')
plt.title('Installs-Rating ', size = 20)
plt.savefig(f"installs_rating.jpg")
plt.show()

# %%
rating = googlestore.iloc[:,2]
correlation = st.pearsonr(installs,rating)
print(f"The correlation between an app's rating and the times it has been installed is {round(correlation[0],2)}")
# Out:
# The correlation between an app's rating and the times it has been installed is 0.05

# %%
plt.figure(figsize=(10,10))
g = sns.boxplot(x="Installs", y="Size", data=googlestore)
g.set_xticklabels(g.get_xticklabels(), rotation=40, ha="right")
plt.title('Installs-Size(kilobyte) ', size = 20)
plt.savefig(f"installs_size.jpg")

# %% [markdown]
# # How do ratings and reviews correlate?

# %%
g = sns.lmplot(y="Reviews", x="Rating", data=googlestore, height=(10))
plt.xscale('linear')
plt.yscale('linear')
plt.title('Rating-Reviews', size = 20)
# Out:
# Text(0.5, 1, 'Rating-Reviews')

# %%
installs = googlestore.iloc[:,5]
rating = googlestore.iloc[:,2]
correlation = st.pearsonr(installs,rating)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.05
