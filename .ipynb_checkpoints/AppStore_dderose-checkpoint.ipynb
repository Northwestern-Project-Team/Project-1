# %%
# Dependencies

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import matplotlib
import scipy.stats as st
import seaborn as sns
from sklearn import datasets
import os

import warnings
warnings.filterwarnings('ignore')

# %%
# Name of the CSV file
csv_path = 'googlestore_clean.csv'

# %%
# The read the CSV file in pandas
googlestore = pd.read_csv(csv_path)
googlestore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating Last Updated
# 0      159   19M      10,000+  Free    0.0       Everyone     7-Jan-18
# 1      967   14M     500,000+  Free    0.0       Everyone    15-Jan-18
# 2    87510  8.7M   5,000,000+  Free    0.0       Everyone     1-Aug-18
# 3   215644   25M  50,000,000+  Free    0.0           Teen     8-Jun-18
# 4      967  2.8M     100,000+  Free    0.0       Everyone    20-Jun-18

# %%
googlestore_df= googlestore[googlestore.Price != 0]
googlestore_df.head()
# Out:
#                                                App       Category  Rating  \
# 223  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 224                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 279  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 280                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 415                             Puffin Browser Pro  COMMUNICATION     4.0
#
#      Reviews                Size  Installs  Type  Price Content Rating  \
# 223    11442                6.8M  100,000+  Paid   4.99       Everyone
# 224    10295                 39M  100,000+  Paid   4.99       Everyone
# 279    11442                6.8M  100,000+  Paid   4.99       Everyone
# 280    10295                 39M  100,000+  Paid   4.99       Everyone
# 415    18247  Varies with device  100,000+  Paid   3.99       Everyone
#
#     Last Updated
# 223    25-Mar-18
# 224    11-Apr-17
# 279    25-Mar-18
# 280    11-Apr-17
# 415     5-Jul-18

# %%
#What is the average price per category? (discounting free apps)
average_price = googlestore_df.groupby(["Category"])['Price'].mean()
average_price_sorted = average_price.sort_values(ascending = False)
average_price_df = pd.DataFrame({'Average Price': average_price_sorted})
average_price_df.style.format({'Average Price': '${:.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_6982d176_3497_11ea_9814_ac87a323642f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Price</th>    </tr>    <tr>        <th class="index_name level0" >Category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row0" class="row_heading level0 row0" >FINANCE</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow0_col0" class="data row0 col0" >$187.68</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row1" class="row_heading level0 row1" >LIFESTYLE</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow1_col0" class="data row1 col0" >$108.94</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row2" class="row_heading level0 row2" >FAMILY</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow2_col0" class="data row2 col0" >$14.18</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row3" class="row_heading level0 row3" >MEDICAL</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow3_col0" class="data row3 col0" >$11.85</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row4" class="row_heading level0 row4" >BUSINESS</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow4_col0" class="data row4 col0" >$6.76</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row5" class="row_heading level0 row5" >DATING</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow5_col0" class="data row5 col0" >$5.74</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row6" class="row_heading level0 row6" >MAPS_AND_NAVIGATION</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow6_col0" class="data row6 col0" >$5.39</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row7" class="row_heading level0 row7" >PHOTOGRAPHY</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow7_col0" class="data row7 col0" >$4.90</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row8" class="row_heading level0 row8" >PARENTING</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow8_col0" class="data row8 col0" >$4.79</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row9" class="row_heading level0 row9" >TRAVEL_AND_LOCAL</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow9_col0" class="data row9 col0" >$4.69</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row10" class="row_heading level0 row10" >EDUCATION</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow10_col0" class="data row10 col0" >$4.49</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row11" class="row_heading level0 row11" >FOOD_AND_DRINK</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow11_col0" class="data row11 col0" >$4.24</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row12" class="row_heading level0 row12" >SPORTS</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow12_col0" class="data row12 col0" >$4.24</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row13" class="row_heading level0 row13" >WEATHER</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow13_col0" class="data row13 col0" >$4.20</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row14" class="row_heading level0 row14" >ENTERTAINMENT</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow14_col0" class="data row14 col0" >$3.99</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row15" class="row_heading level0 row15" >PRODUCTIVITY</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow15_col0" class="data row15 col0" >$3.94</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row16" class="row_heading level0 row16" >HEALTH_AND_FITNESS</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow16_col0" class="data row16 col0" >$3.78</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row17" class="row_heading level0 row17" >GAME</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow17_col0" class="data row17 col0" >$3.64</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row18" class="row_heading level0 row18" >TOOLS</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow18_col0" class="data row18 col0" >$3.30</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row19" class="row_heading level0 row19" >BOOKS_AND_REFERENCE</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow19_col0" class="data row19 col0" >$2.98</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row20" class="row_heading level0 row20" >SHOPPING</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow20_col0" class="data row20 col0" >$2.74</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row21" class="row_heading level0 row21" >VIDEO_PLAYERS</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow21_col0" class="data row21 col0" >$2.62</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row22" class="row_heading level0 row22" >COMMUNICATION</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow22_col0" class="data row22 col0" >$2.58</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row23" class="row_heading level0 row23" >NEWS_AND_MAGAZINES</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow23_col0" class="data row23 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row24" class="row_heading level0 row24" >AUTO_AND_VEHICLES</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow24_col0" class="data row24 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row25" class="row_heading level0 row25" >ART_AND_DESIGN</th>
#                         <td id="T_6982d176_3497_11ea_9814_ac87a323642frow25_col0" class="data row25 col0" >$1.99</td>
#             </tr>
#             <tr>
#                         <th id="T_6982d176_3497_11ea_9814_ac87a323642flevel0_row26" class="row_heading level0 row26" >PERSONALIZATION</th>
#                         <td id="T_6982d176_3497_11ea_98

# %%
#What distribution of free v. paid apps across categories
types = googlestore['Type'].value_counts()
type_labels= googlestore['Type'].value_counts().index
# Out:
# Index(['Free', 'Paid'], dtype='object')

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
#labels = googlestore_df['Category'].value_counts().index
#data = googlestore_df['Category'].value_counts()

types = googlestore['Type'].value_counts()
type_labels= googlestore['Type'].value_counts().index

matplotlib.rcParams['font.size'] = 15
fig, ax = plt.subplots(figsize=(8, 8))

#ax.pie(data,  autopct='%1.1f%%', startangle=90, pctdistance=0.75)
#plt.legend(labels, loc="center")

ax.pie(types,labels=type_labels, radius=0.8,startangle=90, autopct='%1.1f%%', labeldistance=1.05)

#draw circle
#centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0)
#fig = plt.gcf()
#fig.gca().add_artist(centre_circle)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Paid v. Free Apps")
plt.tight_layout()
plt.show()
